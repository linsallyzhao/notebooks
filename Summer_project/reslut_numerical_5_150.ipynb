# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.special import erf
from scipy.stats import norm
from mpl_toolkits.mplot3d import Axes3D
# %matplotlib inline
#%matplotlib tk

# %%
result = pd.read_csv("/home/lin/git/summerProject/HestonNumerical")

# %%
result[['time', 'iteration', 'pv', 'jac', 'lin_sys', 'e0', 'e*', 'Je', 'Dp', 'count','count2', 'count7']].describe()
# Out:
#              time   iteration          pv        jac     lin_sys           e0  \
# count  100.000000  100.000000  100.000000  100.00000  100.000000   100.000000
# mean     1.181225   95.090000  145.340000    9.85000   95.090000    93.010585
# std      2.007840   79.798875  119.047586    7.85651   79.798875   304.770390
# min      0.166682   16.000000   27.000000    2.00000   16.000000     0.093713
# 25%      0.366984   37.750000   58.750000    4.00000   37.750000     9.726969
# 50%      0.632085   68.000000  104.000000    7.00000   68.000000    33.825097
# 75%      1.352011  117.500000  178.500000   12.00000  117.500000    81.054058
# max     18.611459  300.000000  451.000000   30.00000  300.000000  2986.169908
#
#                  e*            Je          Dp      count     count2  count7
# count  1.000000e+02  1.000000e+02  100.000000  100.00000  100.00000   100.0
# mean   2.508816e+01  3.174204e-04    0.000030    1.20000    0.20000     0.0
# ...

# %%
result[['Ok', 'Rk', 'Ovbar', 'Rvbar', 'Ov0', 'Rv0', 'Orho', 'Rrho', 'Osigma', 'Rsigma']].head(50)
# Out:
#           Ok        Rk     Ovbar     Rvbar        Ov0       Rv0      Orho  \
# 0   1.431937  1.091920  0.406948  0.462785   0.262636  0.247063 -0.106159
# 1   3.590508  3.590477  0.887392  0.887393   0.524235  0.524236 -0.705128
# 2   4.921472  4.921476  0.728020  0.728020   0.115418  0.115417 -0.818125
# 3   1.260344  2.770353  0.301588  0.337130   0.455041  0.494579 -0.140067
# 4   1.066167  1.064144  0.669544  0.669610   0.616586  0.616589 -0.218026
# 5   4.799164  4.799340  0.183336  0.183336   0.417883  0.417890 -0.621003
# 6   2.645465  2.643943  0.232924  0.232925   0.861802  0.861506 -0.208087
# 7   2.535666  2.535351  0.888467  0.888507   0.243728  0.243724 -0.606191
# 8   3.659975  3.659930  0.908972  0.908973   0.310382  0.310385 -0.665228
# 9   2.868863  2.862443  0.108685  0.108674   0.490736  0.490049 -0.456819
# 10  2.338012  2.478765  0.791750  0.775985   0.239432  0.240367 -0.644450
# 11  4.229264  4.229186  0.123564  0.123564   0.616622  0.616615 -0.727092
# ...

# %%
result.columns
# Out:
# Index(['Ik', 'Ivbar', 'Iv0', 'Irho', 'Isigma', 'Ok', 'Rk', 'Ovbar', 'Rvbar',
#        'Ov0', 'Rv0', 'Orho', 'Rrho', 'Osigma', 'Rsigma', 'stopped_by', 'time',
#        'iteration', 'pv', 'jac', 'lin_sys', 'e0', 'e*', 'Je', 'Dp', 'count',
#        'count2', 'count7'],
#       dtype='object')

# %%
result['stopped_by'].unique() #3, itmax, 1 small gradient, 5 increase mu
# Out:
# array([1, 6, 3])

# %%
solved = result[result['stopped_by'] == 6]
solved.count().unique()
# Out:
# array([68])

# %%
solved.count().unique()/result.count().unique()
# Out:
# array([0.68])

# %%
solved_first_time = solved[solved['count'] == 1]
solved_first_time.count().unique()
# Out:
# array([66])

# %%
DP = result[result['stopped_by'] == 2]
DP.count().unique()
# Out:
# array([0])

# %%
invalid_value = result[result['stopped_by'] == 7]
invalid_value.count().unique()
# Out:
# array([0])

# %%
DP
# Out:
# Empty DataFrame
# Columns: [Ik, Ivbar, Iv0, Irho, Isigma, Ok, Rk, Ovbar, Rvbar, Ov0, Rv0, Orho, Rrho, Osigma, Rsigma, stopped_by, time, iteration, pv, jac, lin_sys, e0, e*, Je, Dp, count, count2, count7]
# Index: []
#
# [0 rows x 28 columns]

# %%
invalid_value
# Out:
# Empty DataFrame
# Columns: [Ik, Ivbar, Iv0, Irho, Isigma, Ok, Rk, Ovbar, Rvbar, Ov0, Rv0, Orho, Rrho, Osigma, Rsigma, stopped_by, time, iteration, pv, jac, lin_sys, e0, e*, Je, Dp, count, count2, count7]
# Index: []
#
# [0 rows x 28 columns]

# %%
itmax = result[result['stopped_by'] == 3]
itmax.count().unique()
# Out:
# array([6])

# %%
smalJac = result[result['stopped_by'] == 1]
smalJac.count().unique()
# Out:
# array([26])

# %%
solved['time'].describe()
# Out:
# count    68.000000
# mean      0.677949
# std       0.572507
# min       0.166682
# 25%       0.331215
# 50%       0.514135
# 75%       0.785755
# max       3.320020
# Name: time, dtype: float64

# %%
solved_first_time['time'].describe()
# Out:
# count    66.000000
# mean      0.615086
# std       0.437620
# min       0.166682
# 25%       0.331208
# 50%       0.508642
# 75%       0.747086
# max       2.175443
# Name: time, dtype: float64

# %%
solved_first_time['iteration'].describe()
# Out:
# count     66.000000
# mean      62.000000
# std       45.427542
# min       16.000000
# 25%       28.750000
# 50%       50.000000
# 75%       73.750000
# max      241.000000
# Name: iteration, dtype: float64

# %%
solved['iteration'].describe()
# Out:
# count     68.000000
# mean      63.264706
# std       45.340377
# min       16.000000
# 25%       30.250000
# 50%       51.000000
# 75%       80.250000
# max      241.000000
# Name: iteration, dtype: float64

# %%
solved['pv'].describe()
# Out:
# count     68.000000
# mean      98.161765
# std       68.213583
# min       27.000000
# 25%       50.000000
# 50%       82.000000
# 75%      121.250000
# max      367.000000
# Name: pv, dtype: float64

# %%
solved['jac'].describe()
# Out:
# count    68.000000
# mean      6.779412
# std       4.583701
# min       2.000000
# 25%       3.750000
# 50%       6.000000
# 75%       8.000000
# max      25.000000
# Name: jac, dtype: float64

# %%
solved[['Ik', 'Ivbar', 'Iv0', 'Irho', 'Isigma', 'Ok', 'Rk', 'Ovbar', 'Rvbar',
       'Ov0', 'Rv0', 'Orho', 'Rrho', 'Osigma', 'Rsigma', 'stopped_by', 'time']].head()
# Out:
#          Ik     Ivbar       Iv0      Irho    Isigma        Ok        Rk  \
# 1  3.929891  0.092718  0.345411 -0.705128  0.378805  3.590508  3.590477
# 2  2.649793  0.297416  0.199856 -0.818125  0.104508  4.921472  4.921476
# 4  3.434264  0.663212  0.398953 -0.218026  0.811018  1.066167  1.064144
# 5  4.824928  0.229781  0.616342 -0.621003  0.772766  4.799164  4.799340
# 6  4.485418  0.195979  0.378805 -0.208087  0.459777  2.645465  2.643943
#
#       Ovbar     Rvbar       Ov0       Rv0      Orho      Rrho    Osigma  \
# 1  0.887392  0.887393  0.524235  0.524236 -0.705128 -0.623135  0.681029
# 2  0.728020  0.728020  0.115418  0.115417 -0.818125 -0.807766  0.442770
# 4  0.669544  0.669610  0.616586  0.616589 -0.218026 -0.680330  0.850416
# 5  0.183336  0.183336  0.417883  0.417890 -0.621003 -0.551919  0.489785
# 6  0.232924  0.232925  0.861802  0.861506 -0.208087 -0.213617  0.412970
#
#      Rsigma  stopped_by      time
# 1  0.681072           6  0.227517
# ...

# %%
solved[['Ik', 'Ivbar', 'Iv0', 'Irho', 'Isigma', 'Ok', 'Rk', 'Ovbar', 'Rvbar',
       'Ov0', 'Rv0', 'Orho', 'Rrho', 'Osigma', 'Rsigma', 'stopped_by', 'time']].describe()
# Out:
#               Ik      Ivbar        Iv0       Irho     Isigma         Ok  \
# count  68.000000  68.000000  68.000000  68.000000  68.000000  68.000000
# mean    2.964713   0.459248   0.499564  -0.496826   0.436661   2.974142
# std     1.367873   0.244459   0.255593   0.221366   0.265953   1.205044
# min     0.550144   0.080819   0.073706  -0.889944   0.053782   0.651169
# 25%     1.986486   0.256397   0.269227  -0.686655   0.182439   2.008183
# 50%     2.902819   0.414170   0.475093  -0.507712   0.410088   3.026500
# 75%     4.206144   0.671719   0.701832  -0.299179   0.689068   3.858459
# max     4.897572   0.900007   0.940426  -0.114601   0.851408   4.921472
#
#               Rk      Ovbar      Rvbar        Ov0        Rv0       Orho  \
# count  68.000000  68.000000  68.000000  68.000000  68.000000  68.000000
# mean    2.968001   0.488623   0.488597   0.475299   0.474963  -0.496826
# std     1.209489   0.260898   0.260912   0.237198   0.237036   0.221366
# ...

# %%
solved[['Orho', 'Rrho', 'Osigma', 'Rsigma']].iloc[:1000]
# Out:
#         Orho      Rrho    Osigma    Rsigma
# 1  -0.705128 -0.623135  0.681029  0.681072
# 2  -0.818125 -0.807766  0.442770  0.442770
# 4  -0.218026 -0.680330  0.850416  0.849715
# 5  -0.621003 -0.551919  0.489785  0.489663
# 6  -0.208087 -0.213617  0.412970  0.419282
# 7  -0.606191 -0.827138  0.822697  0.824774
# 8  -0.665228 -0.511548 -0.422609  0.422626
# 9  -0.456819 -0.645639  0.868519  0.874971
# 11 -0.727092 -0.270837  0.399860  0.399941
# 13 -0.229350 -0.355022  0.155825  0.155693
# 14 -0.162611 -0.570495  0.437775  0.437763
# 15 -0.375054 -0.852130  0.464771  0.464391
# 17 -0.766946 -0.228219  0.317328  0.317320
# 18 -0.250621 -0.123484  0.490694  0.490687
# 20 -0.300124 -0.649932  0.793165  0.802586
# 21 -0.227806 -0.277334  0.637458  0.637360
# 22 -0.363245 -0.677497  0.098364  0.098325
# 23 -0.561421 -0.199079  0.194100  0.194075
# 24 -0.521951 -0.464058  0.266397  0.266396
# 26 -0.276412 -0.363547  0.515342  0.618587
# 27 -0.573271 -0.286086  0.471268  0.472549
# ...

# %%
solved[solved['Orho'] * solved['Rrho'] < 0].count()
# Out:
# Ik            0
# Ivbar         0
# Iv0           0
# Irho          0
# Isigma        0
# Ok            0
# Rk            0
# Ovbar         0
# Rvbar         0
# Ov0           0
# Rv0           0
# Orho          0
# Rrho          0
# Osigma        0
# Rsigma        0
# stopped_by    0
# time          0
# iteration     0
# pv            0
# jac           0
# lin_sys       0
# e0            0
# e*            0
# Je            0
# Dp            0
# count         0
# count2        0
# count7        0
# dtype: int64

# %%
disIk = np.abs(solved['Ik'] - solved['Rk']).mean()
disIk
# Out:
# 1.3183906895337623

# %%
disIvbar = np.abs(solved['Ivbar'] - solved['Rvbar']).mean()
disIvbar
# Out:
# 0.2558779333368672

# %%
disIv0 = np.abs(solved['Iv0'] - solved['Rv0']).mean()
disIv0
# Out:
# 0.27462763078127633

# %%
disIsigma = np.abs(solved['Isigma'] - solved['Rsigma']).mean()
disIsigma
# Out:
# 0.30296408396301

# %%
disIrho = np.abs(solved['Irho'] - solved['Rrho']).mean()
disIrho
# Out:
# 0.2815863438587717

# %%
disOk = np.abs(solved['Ok'] - solved['Rk']).mean()
disOk
# Out:
# 0.010326950257866466

# %%
disOvbar = np.abs(solved['Ovbar'] - solved['Rvbar']).mean()
disOvbar
# Out:
# 0.00018085173860372828

# %%
disOsigma = (np.abs(solved['Osigma']) - np.abs(solved['Rsigma'])).mean()
disOsigma
# Out:
# -0.005362150602090723

# %%
disOrho = (np.abs(solved['Orho']) - np.abs(solved['Rrho'])).mean()
disOrho
# Out:
# -0.0023247172468061823

# %%
disOv0 = np.abs(solved['Ov0'] - solved['Rv0']).mean()
disOv0
# Out:
# 0.0005968327680037475

# %%
solved.describe()
# Out:
#                 Ik        Ivbar          Iv0         Irho       Isigma  \
# count  8878.000000  8878.000000  8878.000000  8878.000000  8878.000000
# mean      2.839779     0.503683     0.497545    -0.499683     0.500484
# std       1.284128     0.256991     0.259553     0.231691     0.262699
# min       0.500264     0.050188     0.050074    -0.899970     0.050205
# 25%       1.745381     0.285918     0.272610    -0.700868     0.269551
# 50%       2.883985     0.504158     0.494616    -0.498099     0.502299
# 75%       3.953441     0.723633     0.720725    -0.303795     0.728477
# max       4.999459     0.949942     0.949780    -0.100025     0.949989
#
#                 Ok           Rk        Ovbar        Rvbar          Ov0  \
# count  8878.000000  8878.000000  8878.000000  8878.000000  8878.000000
# mean      2.739604     2.739796     0.527108     0.527107     0.471986
# std       1.298493     1.299320     0.254642     0.254651     0.254691
# ...

# %%
solved[solved['iteration']==30]
# Out:
#             Ik     Ivbar       Iv0      Irho    Isigma        Ok        Rk  \
# 77    1.490986  0.262491  0.769627 -0.634046  0.732472  3.939412  3.939334
# 130   0.862139  0.617437  0.854700 -0.839130  0.826624  1.408607  1.411699
# 247   3.011752  0.240952  0.639450 -0.456274  0.824212  1.132023  1.131482
# 261   3.242873  0.295908  0.746932 -0.216498  0.633355  4.234708  4.235667
# 340   4.740762  0.084700  0.317163 -0.287067  0.354950  0.867461  0.865188
# 360   2.363923  0.903952  0.479018 -0.299017  0.200149  1.187901  1.187938
# 361   3.102701  0.860408  0.305838 -0.289019  0.798743  3.391865  3.392061
# 517   0.591684  0.091415  0.088138 -0.810682  0.648596  1.991238  1.992370
# 525   2.803758  0.705094  0.104987 -0.258899  0.776825  3.561165  3.560733
# 776   0.946217  0.175794  0.663288 -0.793941  0.907702  4.839112  4.837104
# 890   1.390849  0.854273  0.060306 -0.674258  0.700752  0.795308  0.793752
# ...

# %%
example = solved[solved.index==77]
example
# Out:
#           Ik     Ivbar       Iv0      Irho    Isigma        Ok        Rk  \
# 77  1.490986  0.262491  0.769627 -0.634046  0.732472  3.939412  3.939334
#
#        Ovbar    Rvbar       Ov0   ...    pv  jac  lin_sys        e0  \
# 77  0.607111  0.60711  0.162443   ...    37   30       36  18.56264
#
#               e*        Je        Dp  count  count2  count7
# 77  4.262171e-12  0.000013  0.000001      1       0       0
#
# [1 rows x 28 columns]

# %%
example.values
# Out:
# array([[ 1.49098603e+00,  2.62491155e-01,  7.69627337e-01,
#         -6.34046495e-01,  7.32472281e-01,  3.93941155e+00,
#          3.93933429e+00,  6.07110577e-01,  6.07109852e-01,
#          1.62443176e-01,  1.62443977e-01, -5.51500600e-01,
#         -5.51629288e-01,  3.50395904e-01,  3.50281522e-01,
#          6.00000000e+00,  5.46694000e-01,  3.00000000e+01,
#          3.70000000e+01,  3.00000000e+01,  3.60000000e+01,
#          1.85626401e+01,  4.26217127e-12,  1.33558296e-05,
#          1.34274732e-06,  1.00000000e+00,  0.00000000e+00,
#          0.00000000e+00]])

# %%
np.abs(example['Ik'] - example['Rk']).values
# Out:
# array([2.44834826])

# %%
np.abs(example['Ivbar'] - example['Rvbar']).values
# Out:
# array([0.3446187])

# %%
np.abs(example['Iv0'] - example['Rv0']).values
# Out:
# array([0.60718336])

# %%
np.abs(example['Isigma'] - example['Rsigma']).values
# Out:
# array([0.38219076])

# %%
np.abs(example['Irho'] - example['Rrho']).values
# Out:
# array([0.08241721])

# %%
realPara = (example[['Rk', 'Rvbar', 'Rv0','Rrho', 'Rsigma']])
realPara.columns = ['k', 'vbar', 'v0', 'rho', 'sigma']
realPara.reset_index(drop=True, inplace=True)
newPara = pd.DataFrame(index=range(31), columns=realPara.columns)
for i in range(31):
    for name in realPara.columns:
        newPara.iloc[i][name] = realPara.iloc[0][name]
newPara
# Out:
#           k     vbar        v0       rho     sigma
# 0   3.93933  0.60711  0.162444 -0.551629  0.350282
# 1   3.93933  0.60711  0.162444 -0.551629  0.350282
# 2   3.93933  0.60711  0.162444 -0.551629  0.350282
# 3   3.93933  0.60711  0.162444 -0.551629  0.350282
# 4   3.93933  0.60711  0.162444 -0.551629  0.350282
# 5   3.93933  0.60711  0.162444 -0.551629  0.350282
# 6   3.93933  0.60711  0.162444 -0.551629  0.350282
# 7   3.93933  0.60711  0.162444 -0.551629  0.350282
# 8   3.93933  0.60711  0.162444 -0.551629  0.350282
# 9   3.93933  0.60711  0.162444 -0.551629  0.350282
# 10  3.93933  0.60711  0.162444 -0.551629  0.350282
# 11  3.93933  0.60711  0.162444 -0.551629  0.350282
# 12  3.93933  0.60711  0.162444 -0.551629  0.350282
# 13  3.93933  0.60711  0.162444 -0.551629  0.350282
# 14  3.93933  0.60711  0.162444 -0.551629  0.350282
# 15  3.93933  0.60711  0.162444 -0.551629  0.350282
# 16  3.93933  0.60711  0.162444 -0.551629  0.350282
# ...

# %%
paraRout = pd.read_csv("/home/lin/git/summerProject/paraRout")
paraRout
# Out:
#            k      vbar        v0       rho     sigma
# 0   1.490986  0.262491  0.769627 -0.634046  0.732472
# 1   1.472749  0.375755  0.425529 -0.629341  0.729757
# 2   1.473742  0.758854  0.302920 -0.690041  0.743077
# 3   1.531484  0.929630  0.224618 -0.600854  0.674571
# 4   1.552526  0.915199  0.179060 -0.417563  0.509666
# 5   1.561817  0.888590  0.170480 -0.270235  0.389824
# 6   1.612263  0.861029  0.163482 -0.152739  0.230131
# 7   1.760889  0.809254  0.159999 -0.073160  0.004850
# 8   2.122378  0.733801  0.156928 -0.073560 -0.041873
# 9   2.649730  0.660720  0.157081 -0.128153  0.395247
# 10  2.738959  0.681305  0.161223 -0.256392  0.222677
# 11  2.821303  0.673186  0.158193 -0.346415  0.190286
# 12  2.992350  0.654548  0.157582 -0.476384  0.135037
# 13  3.265278  0.633612  0.157838 -0.611023  0.158808
# 14  3.544826  0.617082  0.158987 -0.842258  0.135222
# 15  3.740014  0.609859  0.160937 -0.979430  0.153653
# 16  3.840556  0.607024  0.162432 -0.967413  0.171736
# ...

# %%
routs = np.abs(paraRout - newPara)/np.abs(newPara)

# %%
# %matplotlib tk

# %%
plt.semilogy(routs['k'], 'rX-')
plt.semilogy(routs['vbar'], 'bX-')
plt.semilogy(routs['v0'], 'kX-')
plt.semilogy(routs['rho'], 'gX-')
plt.semilogy(routs['sigma'], 'mX-')
plt.legend([r'$|k_k - k^{\star}|/|k^{\star}|$', r'$|\overline{\upsilon}_k - \overline{\upsilon}^{\star}|/|\overline{\upsilon}^{\star}|$', r'$|(\upsilon_0)_k - \upsilon_0^{\star}|/|\upsilon_0^{\star}|$',r'$|\rho_k - \rho^{\star}|/|\rho^{\star}|$',r'$|\sigma_k - \sigma^{\star}|/|\sigma^{\star}|$',], fontsize=22)
plt.xlabel('Index of iteration k', fontsize=24)
plt.ylabel('Nomalized differences between parameters found and targets', fontsize=24)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.grid()

# %%
residual = np.array([ 18.5626,0.656367,0.0386427,0.00612332,0.00397574,0.00263616,0.0021414,0.00167525,0.00119962,0.00109479,0.000611794,0.000388985,0.00028076,0.000157177,6.92636e-05,2.00586e-05,5.23957e-06,3.14254e-06,3.05271e-06,3.02682e-06,2.92439e-06,2.75653e-06,2.43504e-06,2.07694e-06,1.4698e-06,6.76284e-07,1.61719e-07,1.75177e-08,2.01177e-09,1.5531e-10,3.55545e-12])

# %%
plt.semilogy(residual, 'bX-.')
plt.legend(['Reduction path of the objective function'], fontsize=22)
plt.xlabel('Index of iteration k', fontsize=24)
plt.ylabel('Value of the objective function', fontsize=24)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.grid()

# %%
realSPX = np.array([9.1488840741252240e+00,1.7091811411851889e+01,2.2648914959691634e+01,2.6899811014846122e+01,3.0485680583231822e+01,3.3640797740897938e+01,4.0647050370505333e+01,4.7099528768636183e+01,5.7288298801033175e+00,9.2961086466444964e+00,1.2681535166958508e+01,1.5766126995200002e+01,1.8532854376031942e+01,2.1014374258872692e+01,2.6925542643663544e+01,3.1741392486654934e+01,3.6957945727271277e+00,6.6622157345524320e+00,9.2549126095879259e+00,1.1605400673311641e+01,1.3743032942265044e+01,1.5710381405617595e+01,2.0885729383677450e+01,2.5059002842605203e+01,3.7707705228314581e-01,1.8536319875424612e+00,3.7214462167761813e+00,5.4514982430802350e+00,7.5101850404845027e+00,9.3132008534070359e+00,1.4313673212582712e+01,1.8479094744070874e+01,2.4809541410122794e-02,4.8386973821334811e-01,1.4651640721061439e+00,2.7313546456061153e+00,4.1237115119043048e+00,5.5585968310143228e+00,9.8995041607100340e+00,1.3720813274564101e+01])

# %%
realSPX.shape
# Out:
# (40,)

# %%
realVIX = np.array([6.3349628199328215e+01,6.3187554077066345e+01,6.3003396047662946e+01,6.2814838069281329e+01,6.2641277216717100e+01,6.3964437455680489e+01,6.3738105494809929e+01,6.3478651199905201e+01,6.3210519576896800e+01,6.2961530187385691e+01,6.4521373991595809e+01,6.4246055168722648e+01,6.3928225015797580e+01,6.3597344082000319e+01,6.3287945206808118e+01,6.5159862103623183e+01,6.4834143896174936e+01,6.4455224410674617e+01,6.4057533728871405e+01,6.3682788239993997e+01,6.6795373904405139e+01,6.6347261633381493e+01,6.5815955942998244e+01,6.5247066536454270e+01,6.4700717234887705e+01,6.7925725858094481e+01,6.7387484356100458e+01,6.6739908432634024e+01,6.6035775654948395e+01,6.5349603428541727e+01])

# %%
realVIX.shape
# Out:
# (30,)

# %%
initialSPX = np.array([1.3092411920438721e+01,2.1101603296043443e+01,2.6467840574197318e+01,3.0436603181942836e+01,3.3680609427914995e+01,3.6465683205328666e+01,4.2376506607117797e+01,4.7823462527668561e+01,1.0030945406707110e+01,1.4169739288803008e+01,1.7468915721908608e+01,2.0193086372241201e+01,2.2472088574597642e+01,2.4405409127128358e+01,2.8569320856234295e+01,3.1696381337952921e+01,7.9691137080187904e+00,1.1567174203435119e+01,1.4097118899685730e+01,1.6078117946046579e+01,1.7689246663338832e+01,1.9046836600435107e+01,2.2225645771353442e+01,2.4412906487884388e+01,2.8186743897198108e+00,5.6087245214254837e+00,7.7717411622811028e+00,9.2674609096074505e+00,1.0925142927299316e+01,1.2149875550434770e+01,1.5104408648665499e+01,1.7146673518975444e+01,9.5483848802301108e-01,2.7626710363460543e+00,4.3150507943053276e+00,5.6314781374342893e+00,6.7586607266231562e+00,7.7383266714980889e+00,1.0208904090911812e+01,1.1925184313841463e+01])

# %%
initialVIX = np.array([6.4261057083365259e+01,6.4098416682238508e+01,6.3913656945925169e+01,6.3724531991958742e+01,6.3550495986095491e+01,6.3799288234396833e+01,6.3572343266423751e+01,6.3312152365729780e+01,6.3043225398912199e+01,6.2793470780829075e+01,6.3317025302863762e+01,6.3041880980124517e+01,6.2724196347606643e+01,6.2393399164237849e+01,6.2084012683508490e+01,6.2691713144719046e+01,6.2366338348452324e+01,6.1987826163472938e+01,6.1590566228087852e+01,6.1216223171284675e+01,6.0666318427156412e+01,6.0218152569796374e+01,5.9686773498461626e+01,5.9117795174153578e+01,5.8571352767463502e+01,5.8794729499899049e+01,5.8256511426334228e+01,5.7608964271418579e+01,5.6904862186746421e+01,5.6218717539246526e+01])

# %%
optSPX = np.array([9.1488898662351641e+00,1.7091829707794112e+01,2.2648941529008528e+01,2.6899843141972852e+01,3.0485716260263825e+01,3.3640835471815123e+01,4.0647089003364464e+01,4.7099564799562685e+01,5.7288312661176271e+00,9.2961197340644617e+00,1.2681554566557002e+01,1.5766152290572940e+01,1.8532883392976437e+01,2.1014405307932254e+01,2.6925573506035022e+01,3.1741419657594083e+01,3.6957927770505457e+00,6.6622223897680426e+00,9.2549264614453151e+00,1.1605419569119290e+01,1.3743054908842224e+01,1.5710404907385643e+01,2.0885752077053930e+01,2.5059021143732526e+01,3.7707513051300490e-01,1.8536317275657865e+00,3.7214503268607770e+00,5.4515059887458515e+00,7.5101958160127635e+00,9.3132131306655790e+00,1.4313685133673840e+01,1.8479102697243672e+01,2.4809598937907837e-02,4.8387024065828782e-01,1.4651662186596668e+00,2.7313587540253037e+00,4.1237170966109158e+00,5.5586031463946277e+00,9.8995091152294936e+00,1.3720813923161211e+01])

# %%
optVIX = np.array([6.3349773015718817e+01,6.3187699008407726e+01,6.3003541134341440e+01,6.2814983342314811e+01,6.2641422685635618e+01,6.3964591229468788e+01,6.3738258808047568e+01,6.3478803985181244e+01,6.3210671820243121e+01,6.2961681934630242e+01,6.4521529341968474e+01,6.4246210543448711e+01,6.3928380371676440e+01,6.3597499362858322e+01,6.3288100365112726e+01,6.5160009532275680e+01,6.4834291694526939e+01,6.4455372646252385e+01,6.4057682425356518e+01,6.3682937365643433e+01,6.6795513607478469e+01,6.6347401283103210e+01,6.5816095504645020e+01,6.5247205974712443e+01,6.4700856528655194e+01,6.7925850750680084e+01,6.7387609293907047e+01,6.6740033433203678e+01,6.6035900731966194e+01,6.5349728584723110e+01])

# %%
diffInitialSPX = np.abs(realSPX - initialSPX)

# %%
diffInitialVIX = np.abs(realVIX - initialVIX)

# %%
diffOptSPX = np.abs(realSPX - optSPX)*100000
diffOptVIX = np.abs(realVIX - optVIX)*10000

# %%
VIXstrike = np.array([
    
     7.660333466800909, 7.823036262505452, 8.007866879151475,                                     
           8.197064388101637, 8.371167160297436, 7.52823178901193,                 
           7.755350918528184, 8.015741494276396, 8.284874840358377,                
           8.53482112450969, 7.430112345712659, 7.705573455122799,                 
           8.023623852982013, 8.354801898792093, 8.66454459080821,                 
           7.32872469748735, 7.654634796281677, 8.033769704753064,                 
           8.431683207193617, 8.806642128491488, 7.084911309063554,                
           7.534553012964565, 8.067681958626018, 8.638533974549638,                
           9.186775860168481, 6.910110193769552, 7.450988995253548,                
           8.10173736334907, 8.809320258894406, 9.49885695945464
])

# %%
VIXexp = np.array([7, 7, 7, 7, 7, 14, 14, 14, 14, 14, 21, 21, 21, 21, 21, 30, 30, 30, 30, 30, 60, 60, 60, 60, 60, 90, 90, 90, 90, 90])

# %%
SPXstrike = np.array([
    
    93.71, 86.03, 81.12, 77.60, 74.70, 72.16, 66.99,        
                           61.37, 99.56, 98.68, 97.28, 95.88, 94.64, 93.58,        
                           91.75, 90.25, 104.27, 104.63, 104.99, 105.30, 105.62,   
                           105.93, 106.63, 107.66, 122.87, 123.99, 124.85, 126.59, 
                           126.46, 127.15, 128.59, 130.46, 139.39, 141.02, 142.91, 
                           144.56, 146.03, 147.36, 150.05, 153.28
    
])
SPXexp = np.array([30, 60, 90, 120, 150, 180, 270, 360,
                   30, 60, 90, 120, 150, 180, 270, 360,
                   30, 60, 90, 120, 150, 180, 270, 360,
                   30, 60, 90, 120, 150, 180, 270, 360,
                   30, 60, 90, 120, 150, 180, 270, 360])

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.dist=10
for i in range(30):
    ax.plot(np.array([VIXstrike[i], VIXstrike[i]]), np.array([VIXexp[i], VIXexp[i]]), np.array([diffInitialVIX.min()-0.0005, diffInitialVIX[i]]), 'y-.', alpha=0.5)
ax.scatter(VIXstrike, VIXexp, diffInitialVIX, s = 30, depthshade=False)
ax.set_xlabel('Strikes of VIX options', fontsize=24, labelpad=22)
ax.set_ylabel('Maturities of VIX options', fontsize=24, labelpad=22)
ax.set_zlabel('Errors', fontsize=24, labelpad=25)
plt.xticks(fontsize=20)
plt.yticks([7, 14, 21, 30, 60, 90], fontsize=20)
for t in ax.zaxis.get_major_ticks(): t.label.set_fontsize(20)
ax.tick_params(axis='z', which='major', pad=10)
plt.grid()

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.dist=10
ax.scatter(VIXstrike, VIXexp, diffOptVIX, s = 30, depthshade=False)
for i in range(30):
    ax.plot(np.array([VIXstrike[i], VIXstrike[i]]), np.array([VIXexp[i], VIXexp[i]]), np.array([diffOptVIX.min()-0.01, diffOptVIX[i]]), 'y-.', alpha=0.5)
ax.set_xlabel('Strikes of VIX options', fontsize=24, labelpad=22)
ax.set_ylabel('Maturities of VIX options', fontsize=24, labelpad=22)
ax.set_zlabel(r'Errors $\times 10^4$', fontsize=24, labelpad=20)
plt.xticks(fontsize=20)
plt.yticks([7, 14, 21, 30, 60, 90], fontsize=20)
for t in ax.zaxis.get_major_ticks(): t.label.set_fontsize(20)
ax.tick_params(axis='z', which='major', pad=5)
plt.grid()

# %%
diffOptVIX.min()
# Out:
# 1.2489258560322014

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(SPXstrike, SPXexp, diffInitialSPX, s = 30, depthshade=False)
for i in range(40):
    ax.plot(np.array([SPXstrike[i], SPXstrike[i]]), np.array([SPXexp[i], SPXexp[i]]), np.array([diffInitialSPX.min()-0.01, diffInitialSPX[i]]), 'y-.', alpha=0.5)
ax.set_xlabel('Strikes of SPX options', fontsize=24, labelpad=22)
ax.set_ylabel('Maturities of SPX options', fontsize=24, labelpad=22)
ax.set_zlabel('Errors', fontsize=24, labelpad=20)
plt.xticks(fontsize=20)
plt.yticks([30, 60, 90, 120, 150, 180, 270, 360], fontsize=15)
for t in ax.zaxis.get_major_ticks(): t.label.set_fontsize(20)
ax.tick_params(axis='z', which='major', pad=5)
plt.grid()

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(SPXstrike, SPXexp, diffOptSPX, s = 30, depthshade=False)
for i in range(40):
    ax.plot(np.array([SPXstrike[i], SPXstrike[i]]), np.array([SPXexp[i], SPXexp[i]]), np.array([diffOptSPX.min()-0.00000001, diffOptSPX[i]]), 'y-.', alpha=0.5)
ax.set_xlabel('Strikes of SPX options', fontsize=24, labelpad=22)
ax.set_ylabel('Maturities of SPX options', fontsize=24, labelpad=22)
ax.set_zlabel(r'Errors $\times 10^5$', fontsize=24, labelpad=20)
plt.xticks(fontsize=20)
plt.yticks([30, 60, 90, 120, 150, 180, 270, 360], fontsize=15)
for t in ax.zaxis.get_major_ticks(): t.label.set_fontsize(20)
ax.tick_params(axis='z', which='major', pad=10)
plt.grid()
